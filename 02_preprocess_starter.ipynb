# %% [markdown]
# # Preprocessing – Version Simple
# Objectif :
# - Garder uniquement les variables numériques
# - Imputation médiane
# - StandardScaler
# - Export train & test preprocessés

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('data/kaggle_b2_fraud_train_v3.csv')
test = pd.read_csv('data/kaggle_b2_fraud_test_v3.csv')

target = 'target_is_fraud'
id_col = 'customer_id'

# %%
num_cols = train.select_dtypes(include='number').columns.tolist()
num_cols.remove(target)

X_train = train[num_cols]
y_train = train[target]
X_test = test[num_cols]

# %%
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
X_train_processed = pipeline.fit_transform(X_train)
X_test_processed = pipeline.transform(X_test)

# %%
X_test_processed
# Out:
# array([[ 4.05150949e-01,  1.97408034e+00, -4.46862123e-01, ...,
#         -2.95131203e-01,  3.97305419e-01,  9.69924721e-05],
#        [-1.38193243e+00, -7.25390290e-01,  3.13767395e-01, ...,
#         -2.95131203e-01,  3.61217491e-01,  9.69924721e-05],
#        [ 3.20051740e-01, -8.94107204e-01, -2.19367638e-02, ...,
#         -2.95131203e-01, -2.70321248e-01,  9.69924721e-05],
#        ...,
#        [ 9.15746199e-01,  5.68106055e-01,  7.20592547e-01, ...,
#         -2.95131203e-01,  1.78669064e+00,  9.69924721e-05],
#        [-6.16039552e-01, -6.12912347e-01, -1.05983400e+00, ...,
#          4.29712209e+00, -9.37947915e-01,  9.69924721e-05],
#        [-1.72232926e+00,  9.61778856e-01, -6.13095003e-01, ...,
#         -2.95131203e-01,  2.89041635e-01,  9.69924721e-05]])

# %%
X_train_processed = pd.DataFrame(X_train_processed, columns=num_cols)
X_train_processed[target] = y_train.values
X_train_processed[id_col] = train[id_col].values

X_test_processed = pd.DataFrame(X_test_processed, columns=num_cols)
X_test_processed[id_col] = test[id_col].values

# X_train_processed.to_csv('../data/train_preprocessed_simple.csv', index=False)
# X_test_processed.to_csv('../data/test_preprocessed_simple.csv', index=False)

# print('Export terminé.')

# %%
X_train_processed
# Out:
#              age  tenure_months  annual_income_eur  credit_score  \
# 0      -0.360742       5.067224           0.054596     -2.155848
# 1       0.830647      -0.894107          -0.664955      0.563246
# 2      -0.956436      -1.006585          -0.649048      0.853967
# 3       0.575349       1.749124           0.047580      0.563246
# 4      -0.105444       1.580408          -0.202595     -1.300787
# ...          ...            ...                ...           ...
# 159995  1.511441      -1.006585          -0.093733      0.973675
# 159996  0.234953      -0.781629           1.975595      1.709028
# 159997 -0.701139      -0.894107           0.151200      1.161789
# 159998  1.511441      -0.669151          -0.202595      0.836866
# 159999 -1.041536      -0.275479          -0.992604     -0.343119
#
#         num_transactions_30d  avg_amount_30d_eur  max_amount_30d_eur  \
# 0                  -0.083441           -0.004039           -0.858985
# 1                  -0.054686            1.257221            1.103806
# 2                   0.060335            0.308627            0.789774
# 3                  -0.169706           -0.333953           -0.363170
# 4                  -0.284726            0.957613            1.755337
# ...                      ...                 ...                 ...
# 159995             -0.054686           -0.230716           -0.275497
# 159996             -0.140951           -0.210512           -0.495539
# 159997             -0.083441           -0.782133           -0.700469
# 159998              0.060335            0.676977            1.032004
# 159999              0.002824           -0.924298           -0.765994
#
#         days_since_last_login  support_tickets_90d  chargebacks_12m  ...  \
# 0                   -0.591666             0.225939        -0.223690  ...
# 1                   -0.973929            -0.891739        -0.223690  ...
# 2                   -0.616596             0.225939        -0.223690  ...
# 3                    1.103587             0.225939        -0.223690  ...
# 4                    0.064829            -0.891739         4.256265  ...
# ...                       ...                  ...              ...  ...
# 159995              -0.683077            -0.891739        -0.223690  ...
# 159996               0.255960             0.225939        -0.223690  ...
# 159997              -0.940689            -0.891739        -0.223690  ...
# 159998               0.879215             1.343616        -0.223690  ...
# 159999               3.737878             0.225939        -0.223690  ...
#
#         internal_signal_6  internal_signal_7  internal_signal_8  \
# 0                0.109180           0.552249          -0.562089
# 1               -0.403522           0.363602           0.868584
# 2                0.578197           0.290498          -2.204052
# 3                0.639158          -0.889526          -0.817648
# 4                0.079720           0.177623           0.870148
# ...                   ...                ...                ...
# 159995          -0.608636           0.234041          -0.061869
# 159996          -1.790515           0.319336           0.512527
# 159997          -0.324123          -0.060636          -0.992954
# 159998          -0.221680          -1.339675          -0.305497
# 159999           0.399599           0.866201           0.333772
#
#         terms_accepted_flag  partner_risk_indicator  post_event_status_code  \
# 0                       0.0                0.001732               -0.295131
# 1                       0.0                0.001732               -0.295131
# 2                       0.0                0.001732               -0.295131
# 3                       0.0                0.001732               -0.295131
# 4                       0.0                0.001732               -0.295131
# ...                     ...                     ...                     ...
# 159995                  0.0               -8.878158               -0.295131
# 159996                  0.0                0.001732               -0.295131
# 159997                  0.0                0.001732                3.149059
# 159998                  0.0                0.001732               -0.295131
# 159999                  0.0                0.001732               -0.295131
#
#         chargeback_resolution_time_days  legacy_partner_score  \
# 0                              0.198822              0.000097
# 1                             -0.234233              0.000097
# 2                              0.072514              0.000097
# 3                             -0.432717              0.000097
# 4                             -0.342497              0.000097
# ...                                 ...                   ...
# 159995                        -1.046212              0.000097
# 159996                         0.108602              0.000097
# 159997                        -0.035750              0.000097
# 159998                         1.028844              0.000097
# 159999                        -0.144014              0.000097
#
#         target_is_fraud      customer_id
# 0                     0  CUST_6O9Q8D4I36
# 1                     0  CUST_FGUGTW230C
# 2                     0  CUST_8ZI3LCBZ0W
# 3                     0  CUST_5MP3AR41CJ
# 4                     0  CUST_GNPL83JB0J
# ...                 ...              ...
# 159995                0  CUST_I81IW5SVRQ
# 159996                0  CUST_QT6DDEMKTJ
# 159997                0  CUST_I0JS1GTS98
# 159998                0  CUST_L7GUCJ3TFY
# 159999                0  CUST_8IJJ8XKNM9
#
# [160000 rows x 37 columns]
